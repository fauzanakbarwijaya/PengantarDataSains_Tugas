# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#load data
df = pd.read_csv("calon_tni.csv")

# cetak informasi dari data frame
print("========================== Data Calon TNI ==========================")
print("=" * 68)
print(df)
print("=" * 68)

print()
print()

# cetak statistik deskriptif
print("=" * 68)
print("======================= Statistik Deskriptif =======================")
print(df.describe())

print()
print()

# deteksi masalah dalam data / missing value
print("=" * 42)
print("====== Deteksi Masalah Missing Value =====")
print(df.isnull().sum())

print()
print()

# Deteksi Outlier
print("="*30)
print("====== Deteksi Outlier ======")
Q1 = df["gaji"].quantile(0.25) # 25%
Q3 = df["gaji"].quantile(0.75) # 75%
Q = Q3 - Q1

skrip = "outlier_gaji = df[ df[\"gaji\"] > (Q3 + 1.5 * Q) ]"
print(outlier_gaji)

kode diatas, menampilkan hasil dibawah
print(skrip)

outlier_gaji = df[ df["gaji"] > (Q3 + 1.5 * Q) ]
print(outlier_gaji)

print()
print("====== Outlier Gaji ======")
print(f"Outlier Gaji : {len(outlier_gaji)}")

print()
print()

# membuat blox-plot
print("="*30)
print("====== Membuat Blox Plot Gaji ======")
gaji_juta = df['gaji_juta'] = df['gaji'] / 1000000

plt.figure(figsize=(8,6))
plt.boxplot(gaji_juta)
plt.title("Box Plot Gaji Calon TNI")
plt.xlabel("Calon TNI")
plt.ylabel("Gaji (Dalam Juta)")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ========================== Data Calon TNI ==========================
# ====================================================================
#     nama                    alamat  tinggi
# 0   Andi        Jl. Merdeka No. 10     175
# 1   Budi        Jl. Sudirman No. 5     178
# 2  Citra        Jl. Thamrin No. 20     180
# 3   Dewi  Jl. Gatot Subroto No. 15     180
# 4    Eka     Jl. Rasuna Said No. 8     183
# 5  Fajar       Jl. Kuningan No. 12     185
# 6   Gina          Jl. Cikini No. 3     170
# 7   Hadi        Jl. Palmerah No. 7     168
# 8  Indah         Jl. Senayan No. 9     178
# 9  Jilan        Jl. Kuningan No. 2     160
# ====================================================================
#
#
# ====================================================================
# ======================= Statistik Deskriptif =======================
#            tinggi
# count   10.000000
# mean   175.700000
# std      7.645623
# min    160.000000
# 25%    171.250000
# 50%    178.000000
# 75%    180.000000
# max    185.000000
#
#
# ==========================================
# ====== Deteksi Masalah Missing Value =====
# nama      0
# alamat    0
# tinggi    0
# dtype: int64
